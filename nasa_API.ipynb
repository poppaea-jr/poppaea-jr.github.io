#     '20211101': 2.7,
#     '20211102': 2.89,
#     '20211103': 3.24,
#     '20211104': 3.34,
#     '20211105': 3.83,
#     '20211106': 2.96,
#     '20211107': 1.54,
#     '20211108': 1.64,
#     '20211109': 1.05,
#     '20211110': 2.52,
#     '20211111': 2.22,
#     '20211112': 1.03,
#     '20211113': 2.91,
#     '20211114': 3.7,
#     '20211115': 3.89,
#     '20211116': 3.16,
#     '20211117': 3.05,
#     '20211118': 2.21,
#     '20211119': 3.2,
#     '20211120': 2.98,
#     '20211121': 1.6,
#     '20211122': 2.66,
#     '20211123': 3.47,
#     '20211124': 2.6,
#     '20211125': 1.62,
#     '20211126': 2.69,
#     '20211127': 2.73,
#     '20211128': 3.55,
#     '20211129': 3.39,
#     '20211130': 3.2,
#     '20211201': 4.3,
#     '20211202': 3.9,
#     '20211203': 3.16,
#     '20211204': 3.05,
#     '20211205': 3.25,
#     '20211206': 3.66,
#     '20211207': 3.63,
#     '20211208': 4.28,
#     '20211209': 4.07,
#     '20211210': 2.7,
#     '20211211': 0.93,
#     '20211212': 1.1,
#     '20211213': 3.27,
#     '20211214': 4.09,
#     '20211215': 2.48,
#     '20211216': 2.11,
#     '20211217': 1.71,
#     '20211218': 2.8,
#     '20211219': 3.41,
#     '20211220': 2.76,
#     '20211221': 2.79,
#     '20211222': 2.12,
#     '20211223': 3.17,
#     '20211224': 1.76,
#     '20211225': 2.3,
#     '20211226': 3.74,
#     '20211227': 3.73,
#     '20211228': 6.07,
#     '20211229': 5.79,
#     '20211230': 6.08,
#     '20211231': 5.98,
#     '20220101': 5.89,
#     '20220102': 3.9,
#     '20220103': 4.25,
#     '20220104': 5.3,
#     '20220105': 4.95,
#     '20220106': 5.24,
#     '20220107': 4.83,
#     '20220108': 5.71,
#     '20220109': 5.79,
#     '20220110': 4.98}}},
#  'times': {'data': 2.128, 'process': 0.07},
#  'type': 'Feature'}

# %%
from pandas import json_normalize

# %%
df = json_normalize(data)

# %%
df = df.T

# %%
df
# Out:
#                                                                           0
# type                                                                Feature
# messages                                                                 []
# geometry.type                                                         Point
# geometry.coordinates                 [51.45904975, -2.603436197922635, 0.0]
# properties.parameter.WS10M.20210110                                     6.6
# ...                                                                     ...
# header.end                                                         20220110
# parameters.WS10M.units                                                  m/s
# parameters.WS10M.longname                           Wind Speed at 10 Meters
# times.data                                                            2.128
# times.process                                                          0.07
#
# [380 rows x 1 columns]

# %%
df = df.iloc[4: , :]

# %%
df
# Out:
#                                                            0
# properties.parameter.WS10M.20210110                      6.6
# properties.parameter.WS10M.20210111                     5.58
# properties.parameter.WS10M.20210112                     6.11
# properties.parameter.WS10M.20210113                     5.41
# properties.parameter.WS10M.20210114                     3.62
# ...                                                      ...
# header.end                                          20220110
# parameters.WS10M.units                                   m/s
# parameters.WS10M.longname            Wind Speed at 10 Meters
# times.data                                             2.128
# times.process                                           0.07
#
# [376 rows x 1 columns]

# %%
df = df.iloc[:-12]

# %%
df
# Out:
#                                         0
# properties.parameter.WS10M.20210110   6.6
# properties.parameter.WS10M.20210111  5.58
# properties.parameter.WS10M.20210112  6.11
# properties.parameter.WS10M.20210113  5.41
# properties.parameter.WS10M.20210114  3.62
# ...                                   ...
# properties.parameter.WS10M.20220104   5.3
# properties.parameter.WS10M.20220105  4.95
# properties.parameter.WS10M.20220106  5.24
# properties.parameter.WS10M.20220107  4.83
# properties.parameter.WS10M.20220108  5.71
#
# [364 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 364 entries, properties.parameter.WS10M.20210110 to properties.parameter.WS10M.20220108
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   0       364 non-null    object
# dtypes: object(1)
# memory usage: 5.7+ KB

# %%
df = df.reset_index()

# %%
df
# Out:
#                                    index     0
# 0    properties.parameter.WS10M.20210110   6.6
# 1    properties.parameter.WS10M.20210111  5.58
# 2    properties.parameter.WS10M.20210112  6.11
# 3    properties.parameter.WS10M.20210113  5.41
# 4    properties.parameter.WS10M.20210114  3.62
# ..                                   ...   ...
# 359  properties.parameter.WS10M.20220104   5.3
# 360  properties.parameter.WS10M.20220105  4.95
# 361  properties.parameter.WS10M.20220106  5.24
# 362  properties.parameter.WS10M.20220107  4.83
# 363  properties.parameter.WS10M.20220108  5.71
#
# [364 rows x 2 columns]

# %%
df = df.rename(columns={0: "wind"})

# %%
df
# Out:
#                                    index  wind
# 0    properties.parameter.WS10M.20210110   6.6
# 1    properties.parameter.WS10M.20210111  5.58
# 2    properties.parameter.WS10M.20210112  6.11
# 3    properties.parameter.WS10M.20210113  5.41
# 4    properties.parameter.WS10M.20210114  3.62
# ..                                   ...   ...
# 359  properties.parameter.WS10M.20220104   5.3
# 360  properties.parameter.WS10M.20220105  4.95
# 361  properties.parameter.WS10M.20220106  5.24
# 362  properties.parameter.WS10M.20220107  4.83
# 363  properties.parameter.WS10M.20220108  5.71
#
# [364 rows x 2 columns]

# %%
df = df.rename(columns={"index": "date"})

# %%
df
# Out:
#                                     date  wind
# 0    properties.parameter.WS10M.20210110   6.6
# 1    properties.parameter.WS10M.20210111  5.58
# 2    properties.parameter.WS10M.20210112  6.11
# 3    properties.parameter.WS10M.20210113  5.41
# 4    properties.parameter.WS10M.20210114  3.62
# ..                                   ...   ...
# 359  properties.parameter.WS10M.20220104   5.3
# 360  properties.parameter.WS10M.20220105  4.95
# 361  properties.parameter.WS10M.20220106  5.24
# 362  properties.parameter.WS10M.20220107  4.83
# 363  properties.parameter.WS10M.20220108  5.71
#
# [364 rows x 2 columns]

# %%
for x in range(0,len(df)):
  df['date'][x] = df['date'][x][27:]

# %%
df
# Out:
#          date  wind
# 0    20210110   6.6
# 1    20210111  5.58
# 2    20210112  6.11
# 3    20210113  5.41
# 4    20210114  3.62
# ..        ...   ...
# 359  20220104   5.3
# 360  20220105  4.95
# 361  20220106  5.24
# 362  20220107  4.83
# 363  20220108  5.71
#
# [364 rows x 2 columns]

# %%
import pandas as pd

# %%
df["date"] = pd.to_datetime(df["date"])

# %%
df
# Out:
#           date  wind
# 0   2021-01-10   6.6
# 1   2021-01-11  5.58
# 2   2021-01-12  6.11
# 3   2021-01-13  5.41
# 4   2021-01-14  3.62
# ..         ...   ...
# 359 2022-01-04   5.3
# 360 2022-01-05  4.95
# 361 2022-01-06  5.24
# 362 2022-01-07  4.83
# 363 2022-01-08  5.71
#
# [364 rows x 2 columns]

# %%
df.to_csv("senate_wind.csv", index = False)

# %%
from google.colab import files

# %%
files.download("senate_wind.csv")
